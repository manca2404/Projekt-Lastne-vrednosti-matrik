# %%
import matplotlib.pyplot as plt

# Vse točke iz titlePoints
titlePoints = [
    {"x":10.3,"y":179.8},
    {"x":15.6,"y":179.8},
    {"x":20.9,"y":179.8},
    {"x":26.1,"y":179.8},
    {"x":31.4,"y":179.8},
    {"x":36.6,"y":179.8},
    {"x":41.9,"y":179.8},
    {"x":47.1,"y":179.8},
    {"x":48.5,"y":176.0},
    {"x":48.5,"y":170.7},
    {"x":48.5,"y":165.5},
    {"x":48.5,"y":160.2},
    {"x":48.5,"y":155.0},
    {"x":48.5,"y":149.7},
    {"x":48.5,"y":144.5},
    {"x":48.5,"y":139.2},
    {"x":48.5,"y":134.0},
    {"x":48.5,"y":128.7},
    {"x":48.5,"y":123.5},
    {"x":48.5,"y":118.2},
    {"x":48.5,"y":113.0},
    {"x":48.5,"y":107.7},
    {"x":48.5,"y":102.5},
    {"x":50.1,"y":98.9},
    {"x":55.4,"y":98.9},
    {"x":60.6,"y":98.9},
    {"x":65.9,"y":98.9},
    {"x":71.1,"y":98.9},
    {"x":76.4,"y":98.8},
    {"x":81.6,"y":98.8},
    {"x":82.7,"y":103.0},
    {"x":82.7,"y":108.3},
    {"x":79.3,"y":110.1},
    {"x":74.1,"y":110.1},
    {"x":68.8,"y":110.1},
    {"x":64.9,"y":111.5},
    {"x":64.9,"y":116.8},
    {"x":64.9,"y":122.0},
    {"x":64.9,"y":127.3},
    {"x":65.5,"y":132.0},
    {"x":70.7,"y":132.0},
    {"x":76.0,"y":132.0},
    {"x":80.0,"y":133.2},
    {"x":80.0,"y":138.4},
    {"x":79.8,"y":143.5},
    {"x":74.5,"y":143.5},
    {"x":69.3,"y":143.5},
    {"x":64.9,"y":144.3},
    {"x":64.9,"y":149.6},
    {"x":64.9,"y":154.8},
    {"x":64.9,"y":160.1},
    {"x":64.9,"y":165.3},
    {"x":64.9,"y":170.6},
    {"x":64.9,"y":175.8},
    {"x":66.1,"y":179.8},
    {"x":71.4,"y":179.8},
    {"x":76.6,"y":179.8},
    {"x":81.9,"y":179.8},
    {"x":87.1,"y":179.8},
    {"x":92.4,"y":179.8},
    {"x":97.6,"y":179.8},
    {"x":102.9,"y":179.8},
    {"x":108.1,"y":179.8},
    {"x":113.4,"y":179.8},
    {"x":118.6,"y":179.8},
    {"x":123.9,"y":179.8},
  
   
]


# Razdeli X in Y
x = [p['x'] for p in titlePoints]
y = [p['y'] for p in titlePoints]

# Nariši črko F
plt.figure(figsize=(6,8))
plt.plot(x, y, '-o', color='blue')
plt.gca().invert_yaxis()  # orientacija prava
plt.axis('equal')
plt.title("Črka F")
plt.show()

# %%
import matplotlib.pyplot as plt

# Prva F
F_points = [
    
    {"x":26.1,"y":179.8}, {"x":31.4,"y":179.8}, {"x":36.6,"y":179.8},
    {"x":41.9,"y":179.8}, {"x":47.1,"y":179.8}, {"x":48.5,"y":176.0},
    {"x":48.5,"y":170.7}, {"x":48.5,"y":165.5}, {"x":48.5,"y":160.2},
    {"x":48.5,"y":155.0}, {"x":48.5,"y":149.7}, {"x":48.5,"y":144.5},
    {"x":48.5,"y":139.2}, {"x":48.5,"y":134.0}, {"x":48.5,"y":128.7},
    {"x":48.5,"y":123.5}, {"x":48.5,"y":118.2}, {"x":48.5,"y":113.0},
    {"x":48.5,"y":107.7}, {"x":48.5,"y":102.5}, {"x":50.1,"y":98.9},
    {"x":55.4,"y":98.9}, {"x":60.6,"y":98.9}, {"x":65.9,"y":98.9},
    {"x":71.1,"y":98.9}, {"x":76.4,"y":98.8}, {"x":81.6,"y":98.8},
    {"x":82.7,"y":103.0}, {"x":82.7,"y":108.3}, {"x":79.3,"y":110.1},
    {"x":74.1,"y":110.1}, {"x":68.8,"y":110.1}, {"x":64.9,"y":111.5},
    {"x":64.9,"y":116.8}, {"x":64.9,"y":122.0}, {"x":64.9,"y":127.3},
    {"x":65.5,"y":132.0}, {"x":70.7,"y":132.0}, {"x":76.0,"y":132.0},
    {"x":80.0,"y":133.2}, {"x":80.0,"y":138.4}, {"x":79.8,"y":143.5},
    {"x":74.5,"y":143.5}, {"x":69.3,"y":143.5}, {"x":64.9,"y":144.3},
    {"x":64.9,"y":149.6}, {"x":64.9,"y":154.8}, {"x":64.9,"y":160.1},
    {"x":64.9,"y":165.3}, {"x":64.9,"y":170.6}, {"x":64.9,"y":175.8},
    {"x":66.1,"y":179.8}, {"x":71.4,"y":179.8}, {"x":76.6,"y":179.8},
    {"x":81.9,"y":179.8}, {"x":87.1,"y":179.8}, {"x":92.4,"y":179.8},
    {"x":98.6,"y":179.8}, 
]

# ===== NOVI M – PREMAKNJEN V LEVO =====
scale_x = 1.4
shift_x = -180
vert_shift = 2  # manjši premik navpičnih črt v levo

M_points = [
   
   
 
    {"x":490.0,"y":219.7},
    {"x":490.1,"y":224.9},
    {"x":490.2,"y":230.2},
    {"x":490.3,"y":235.4},
    {"x":490.4,"y":240.7},
    {"x":490.4,"y":245.9},
    {"x":490.5,"y":251.2},
    {"x":490.6,"y":256.4},
    {"x":490.7,"y":261.7},
    {"x":490.8,"y":266.9},
    {"x":490.9,"y":272.2},
    {"x":491.0,"y":277.4},
    {"x":491.1,"y":282.7},
    {"x":491.2,"y":287.9},
    {"x":491.3,"y":293.2},
    {"x":491.4,"y":298.4},
    {"x":487.8,"y":300.1},
    {"x":482.6,"y":300.1},
    {"x":479.4,"y":297.9},
    {"x":479.3,"y":292.7},
    {"x":479.2,"y":287.4},
    {"x":479.0,"y":282.2},
    {"x":478.9,"y":276.9},
    {"x":478.8,"y":271.7},
    {"x":478.7,"y":266.4},
    {"x":478.5,"y":261.2},
    {"x":478.4,"y":255.9},
    {"x":478.3,"y":250.7},
    {"x":478.2,"y":245.4},
    {"x":477.2,"y":249.9},
    {"x":476.3,"y":255.0},
    {"x":475.3,"y":260.2},
    {"x":474.3,"y":265.3},
    {"x":473.3,"y":270.5},
    {"x":472.4,"y":275.7},
    {"x":471.4,"y":280.8},
    {"x":470.4,"y":286.0},
    {"x":469.4,"y":291.1},
    {"x":468.5,"y":296.3},
    {"x":466.3,"y":300.1},
    {"x":461.1,"y":300.1},
    {"x":457.2,"y":298.3},
    {"x":456.2,"y":293.2},
    {"x":455.2,"y":288.0},
    {"x":454.2,"y":282.9},
    {"x":453.2,"y":277.7},
    {"x":452.2,"y":272.6},
    {"x":451.2,"y":267.4},
    {"x":450.2,"y":262.3},
    {"x":449.2,"y":257.1},
    {"x":448.2,"y":251.9},
    {"x":447.2,"y":246.8},
    {"x":446.8,"y":247.9},
    {"x":446.7,"y":253.2},
    {"x":446.6,"y":258.4},
    {"x":446.4,"y":263.7},
    {"x":446.3,"y":268.9},
    {"x":446.2,"y":274.2},
    {"x":446.1,"y":279.4},
    {"x":446.0,"y":284.7},
    {"x":445.9,"y":289.9},
    {"x":445.8,"y":295.2},
    {"x":445.3,"y":300.1},
    {"x":440.0,"y":300.1},
    {"x":434.8,"y":300.1},
    {"x":433.6,"y":296.0},
    {"x":433.7,"y":290.8},
    {"x":433.8,"y":285.5},
    {"x":433.9,"y":280.3},
    {"x":434.0,"y":275.0},
    {"x":434.1,"y":269.8},
    {"x":434.2,"y":264.5},
    {"x":434.3,"y":259.3},
    {"x":434.3,"y":254.0},
    {"x":434.4,"y":248.8},
    {"x":434.5,"y":243.5},
    {"x":434.6,"y":238.3},
    {"x":434.7,"y":233.0},
    {"x":434.8,"y":227.8},
    {"x":434.9,"y":222.5},
   
   
]

# Obrni vrstni red točk črke M
M_points_reversed = list(reversed(M_points))

move_x = -335   # levo (-) / desno (+)
move_y = -120    # gor (-) / dol (+)

M_moved = [
    {"x": p["x"] + move_x, "y": p["y"] + move_y}
    for p in M_points_reversed
]

# Druga F desno
shift_F_right = 130
F2_points = [{"x":p["x"] + shift_F_right, "y":p["y"]} for p in F_points]

# Združi vse
titlePoints = F_points + M_moved + F2_points

# Risanje
x = [p['x'] for p in titlePoints]
y = [p['y'] for p in titlePoints]

plt.figure(figsize=(16,8))
plt.plot(x, y, '-o', color='blue')
plt.gca().invert_yaxis()
plt.axis('equal')
plt.title("Črke F M F (M premaknjen malo v levo)")
plt.show()

# %%
import matplotlib.pyplot as plt

# Prva F
F_ = [
    {"x":114,"y":210.25},
    {"x":122,"y":208.25},
    {"x":130,"y":206.25},
    {"x":138,"y":206.25},
    {"x":146,"y":206.25},
    {"x":154,"y":202.25},
    {"x":164,"y":202.25},
    {"x":174,"y":204.25},
    {"x":182,"y":206.25},
    {"x":188,"y":208.25},
    {"x":194,"y":210.25},
    {"x":200,"y":212.25},
    {"x":206,"y":216.25},
    {"x":210,"y":222.25},
    {"x":212,"y":228.25},
    {"x":214,"y":234.25},
    {"x":216,"y":240.25},
    {"x":216,"y":248.25},
    {"x":216,"y":240.25},
    {"x":212,"y":234.25},
    {"x":206,"y":230.25},
    {"x":200,"y":228.25},
    {"x":194,"y":226.25},
    {"x":186,"y":226.25},
    {"x":180,"y":228.25},
    {"x":174,"y":234.25},
    {"x":170,"y":240.25},
    {"x":170,"y":250.25},
    {"x":170,"y":258.25},
    {"x":172,"y":264.25},
    {"x":178,"y":270.25},
    {"x":184,"y":268.25},
    {"x":188,"y":262.25},
    {"x":190,"y":256.25},
    {"x":192,"y":250.25},
    {"x":190,"y":242.25},
    {"x":186,"y":236.25},
    {"x":180,"y":234.25},
    {"x":172,"y":234.25},
    {"x":164,"y":234.25},
    {"x":158,"y":236.25},
    {"x":150,"y":238.25},
    {"x":144,"y":242.25},
    {"x":140,"y":248.25},
    {"x":144,"y":242.25},
    {"x":150,"y":240.25},
    {"x":156,"y":234.25},
    {"x":162,"y":232.25},
    {"x":168,"y":228.25},
    {"x":174,"y":226.25},
    {"x":180,"y":224.25},
    {"x":186,"y":220.25},
    {"x":192,"y":218.25},
    {"x":198,"y":216.25},
    {"x":206,"y":216.25},
    {"x":214,"y":218.25},
    {"x":216,"y":224.25},
    {"x":222,"y":226.25},
    {"x":230,"y":226.25},
    {"x":238,"y":226.25},
    {"x":246,"y":226.25},
    {"x":254,"y":226.25},
    {"x":260,"y":224.25},
    {"x":266,"y":220.25},
    {"x":272,"y":216.25},
    {"x":278,"y":214.25},
    {"x":284,"y":212.25},
    {"x":290,"y":208.25},
    {"x":296,"y":206.25},
    {"x":304,"y":206.25},
    {"x":312,"y":206.25},
    {"x":320,"y":206.25},
    {"x":326,"y":208.25},
    {"x":332,"y":212.25},
    {"x":336,"y":218.25},
    {"x":340,"y":224.25},
    {"x":344,"y":230.25},
    {"x":344,"y":238.25},
    {"x":342,"y":230.25},
    {"x":340,"y":224.25},
    {"x":334,"y":220.25},
    {"x":328,"y":216.25},
    {"x":320,"y":216.25},
    {"x":314,"y":220.25},
    {"x":310,"y":226.25},
    {"x":306,"y":234.25},
    {"x":306,"y":242.25},
    {"x":306,"y":250.25},
    {"x":308,"y":256.25},
    {"x":316,"y":256.25},
    {"x":320,"y":250.25},
    {"x":322,"y":242.25},
    {"x":322,"y":234.25},
    {"x":322,"y":226.25},
    {"x":320,"y":220.25},
    {"x":314,"y":218.25},
    {"x":306,"y":218.25},
    {"x":300,"y":222.25},
    {"x":294,"y":226.25},
    {"x":288,"y":230.25},
    {"x":282,"y":236.25},
    {"x":280,"y":242.25},
    {"x":286,"y":238.25},
    {"x":292,"y":232.25},
    {"x":296,"y":226.25},
    {"x":300,"y":220.25},
    {"x":306,"y":218.25},
    {"x":314,"y":214.25},
    {"x":320,"y":210.25},
    {"x":326,"y":208.25},
    {"x":334,"y":208.25},
    {"x":342,"y":208.25},
    {"x":350,"y":208.25},
    {"x":356,"y":210.25},
    {"x":362,"y":212.25},
    {"x":362,"y":220.25},
    {"x":362,"y":228.25},
    {"x":360,"y":234.25},
    {"x":358,"y":240.25},
    {"x":356,"y":246.25},
    {"x":354,"y":252.25},
    {"x":352,"y":258.25},
    {"x":350,"y":264.25},
    {"x":348,"y":270.25},
    {"x":344,"y":276.25},
    {"x":338,"y":280.25},
    {"x":332,"y":282.25},
    {"x":326,"y":284.25},
    {"x":320,"y":286.25},
    {"x":312,"y":286.25},
    {"x":304,"y":286.25},
    {"x":296,"y":286.25},
    {"x":288,"y":286.25},
    {"x":282,"y":284.25},
    {"x":276,"y":278.25},
    {"x":272,"y":272.25},
    {"x":266,"y":268.25},
    {"x":264,"y":262.25},
    {"x":262,"y":254.25},
    {"x":262,"y":246.25},
    {"x":258,"y":240.25},
    {"x":252,"y":236.25},
    {"x":250,"y":242.25},
    {"x":250,"y":250.25},
    {"x":250,"y":258.25},
    {"x":250,"y":266.25},
    {"x":250,"y":274.25},
    {"x":252,"y":280.25},
    {"x":258,"y":282.25},
    {"x":260,"y":288.25},
    {"x":262,"y":294.25},
    {"x":264,"y":300.25},
    {"x":264,"y":308.25},
    {"x":264,"y":316.25},
    {"x":262,"y":322.25},
    {"x":254,"y":322.25},
    {"x":254,"y":330.25},
    {"x":254,"y":338.25},
    {"x":252,"y":344.25},
    {"x":250,"y":350.25},
    {"x":258,"y":352.25},
    {"x":266,"y":352.25},
    {"x":274,"y":352.25},
    {"x":282,"y":352.25},
    {"x":288,"y":350.25},
    {"x":294,"y":352.25},
    {"x":302,"y":352.25},
    {"x":300,"y":358.25},
    {"x":294,"y":360.25},
    {"x":288,"y":362.25},
    {"x":282,"y":364.25},
    {"x":274,"y":364.25},
    {"x":266,"y":364.25},
    {"x":258,"y":364.25},
    {"x":250,"y":364.25},
    {"x":242,"y":364.25},
    {"x":234,"y":364.25},
    {"x":226,"y":364.25},
    {"x":218,"y":364.25},
    {"x":212,"y":362.25},
    {"x":206,"y":360.25},
    {"x":200,"y":358.25},
    {"x":198,"y":352.25},
    {"x":206,"y":352.25},
    {"x":214,"y":352.25},
    {"x":222,"y":354.25},
    {"x":230,"y":354.25},
    {"x":238,"y":354.25},
    {"x":246,"y":354.25},
    {"x":252,"y":352.25},
    {"x":252,"y":344.25},
    {"x":252,"y":336.25},
    {"x":252,"y":328.25},
    {"x":250,"y":322.25},
    {"x":244,"y":324.25},
]

# Risanje
x = [p['x'] for p in F_]
y = [p['y'] for p in F_]

plt.figure(figsize=(16,8))
plt.plot(x, y, '-o', color='blue')
plt.gca().invert_yaxis()
plt.axis('equal')
plt.title("Črka F")
plt.show()
